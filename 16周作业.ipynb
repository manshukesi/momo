# %%
import pandas as pd
import mytools

# %%
认同数据表 = mytools.读取SPSS数据文件(R'data\国家认同数据清理后.sav')

cross_tab = pd.crosstab(index=[认同数据表['年级'], 认同数据表['世博会']], 
                        columns=认同数据表['政治面貌'], 
                        margins=True, normalize=True)  

cross_tab
# Out:
# 政治面貌            团员        党员        群众        其他       All
# 年级  世博会
# 预科  没感觉   0.001284  0.000000  0.000000  0.000000  0.001284
#     一般    0.005135  0.000000  0.000000  0.000000  0.005135
#     比较好   0.005135  0.000000  0.001284  0.000000  0.006418
#     感到自豪  0.003851  0.000000  0.000000  0.000000  0.003851
# 大一  没感觉   0.008986  0.000000  0.000000  0.000000  0.008986
#     一般    0.038511  0.000000  0.003851  0.000000  0.042362
#     比较好   0.053915  0.008986  0.014121  0.001284  0.078306
#     感到自豪  0.189987  0.006418  0.015404  0.002567  0.214377
# 大二  没感觉   0.007702  0.001284  0.000000  0.000000  0.008986
#     一般    0.024390  0.008986  0.003851  0.002567  0.039795
#     比较好   0.064185  0.014121  0.015404  0.001284  0.094994
#     感到自豪  0.148909  0.010270  0.014121  0.002567  0.175866
# 大三  没感觉   0.003851  0.002567  0.000000  0.000000  0.006418
#     一般    0.017972  0.012837  0.010270  0.002567  0.043646
#     比较好   0.028241  0.017972  0.010270  0.000000  0.056483
#     感到自豪  0.061617  0.023107  0.007702  0.007702  0.100128
# 大四  没感觉   0.001284  0.000000  0.000000  0.000000  0.001284
#     一般    0.010270  0.002567  0.005135  0.000000  0.017972
#     比较好   0.016688  0.014121  0.001284  0.000000  0.032092
#     感到自豪  0.044929  0.008986  0.007702  0.000000  0.061617
# All       0.736842  0.132221  0.110398  0.020539  1.000000

# %%
from scipy import stats
specific_grade = '大三'


df_specific_grade = 认同数据表[认同数据表['年级'] == specific_grade]

cross_tab_specific_grade = pd.crosstab(df_specific_grade['中国传统文化'], df_specific_grade['政治面貌'])
#卡方检验
chi2_grade, p_grade, dof_grade, expected_grade = stats.chi2_contingency(cross_tab_specific_grade)

print(chi2_grade,p_grade)
cross_tab_specific_grade
# Out:
# 4.249014702933199 0.6430181226688128
# 政治面貌       团员  党员  群众  其他
# 中国传统文化
# 古板，跟不上潮流    3   1   2   0
# 比较肯定       25  10   8   2
# 富有内涵，意义深刻  59  33  12   6

# %%
cross_tab_specific_grade = pd.crosstab(认同数据表['中国传统文化'], 认同数据表['政治面貌'])

# 进行卡方检验
chi2_grade, p_grade, dof_grade, expected_grade = stats.chi2_contingency(cross_tab_specific_grade)
print(chi2_grade, p_grade)
# Out:
# 18.475218338258383 0.005148117547376877
