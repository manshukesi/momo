# %%
import pandas as pd
import numpy as np

# %%
df1= pd.read_spss(R'问卷数据-转化前.sav')

# %%
import pyreadstat

# %%
d=pyreadstat.read_sav(R'问卷数据-转化前.sav')

# %%
d[0]
# Out:
#            作答ID   作答时长      省份      Q1 Q2 Q3 Q4_1 Q4_2 Q4_3 Q4_4  ... Q5_4  \
# 0   NENDV0POozm   39.0     青海省  18-25岁  男  否    0    1    1    1  ...    1
# 1   lav5j439Amg   42.0     青海省  18-25岁  女  否    1    0    1    1  ...    0
# 2   lavzrlaxG1g   42.0     北京市  18-25岁  男  是    1    0    0    0  ...    0
# 3   opA9varKbEd   50.0     青海省  18-25岁  女  否    1    1    0    0  ...    0
# 4   opA9pAdmnxd  165.0     青海省  18-25岁  女  否    0    0    0    1  ...    1
# 5   XE3bEjXDA5D   64.0     青海省  18-25岁  男  否    1    1    0    0  ...    0
# 6   mjJmPnQYxvp   38.0     青海省  18-25岁  女  否    1    1    1    1  ...    0
# 7   n4p6xBoGXJN   45.0     青海省  18-25岁  男  是    0    1    0    0  ...    0
# 8   g4aBjrNrljl   42.0     青海省  26-35岁  男  否    1    1    0    0  ...    0
# 9   XE3bpkAK44B   35.0     青海省  18-25岁  男  否    1    0    1    1  ...    0
# 10  n4p65ZawnVa   14.0     青海省  26-35岁  男  是    0    1    0    0  ...    0
# ...

# %%
d = pyreadstat.read_sav(R'问卷数据-转化前.sav')[0]
